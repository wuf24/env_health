# %% [markdown]
# ### 单个细菌的固定效应模型（13个）
#
# 主要关注：R1xday 抗生素
#
# 因素间的贡献性：VIF
#
# 菌的固定效应（菌的耐药率放成y轴）
# > 13个耐药拆分开，分别对应 ，y值变成：239*13
# > 细菌耐药类型（13个AMR） yes
# >
#
#
# 机器学习：Association of health, nutrition, and socioeconomic variables with global antimicrobial resistance: a modelling study
#
# 贝叶斯：OR值
#
# 非线性方法：（不好解释）GAM广义加性模型、odds ratio

# %%
先做固定效应（29个因素）
从中选几个相关性强、生物学意义强的、解释程度比较高的，r2高、n值大

不固定省份（省份已经从GDP等因素可以说明）
省份、年份，都不固定，用多元线性回归（多元GAM、GLM线性回归）

敏感性分析和不确定分析：
    用同样的因素去跑GAM、GLM、贝叶斯、随机森林(因素对AMR的贡献程度)

最主要的还是综合的（主线）
